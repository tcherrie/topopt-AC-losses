# %% [markdown]
# # Parametric and topology optimization of conductors in electrical machines
# ___
# ## Notebooks
# - [I_reference_simulation](I_reference_simulation.ipynb)
# - [II_taylor_tests](II_taylor_tests.ipynb)
# - [III_single_material_optimization](III_single_material_optimization.ipynb)
# - [IV_multi_material_optimization](IV_multi_material_optimization.ipynb)
# - [V_topology_optimization](V_topology_optimization.ipynb)

# %% [markdown]
# ___
# ## References

# %%
## References
